// %% [markdown]
// # 2021년 2학기 객체지향프로그래밍 HW1
// - 이름: ???
// - 학번: ????????

// %%
class Org { // 클래스 내용을 적절히 작성하라
}

// %%
class Member { // 클래스 내용을 적절히 작성하라
}

// %%
var org1 = new Org("심씨네가전","유한회사");
var org2 = new Org("호호식품","주식회사");

// %%
var 심순이 = new Member(org1, "심순이","사장");
var 민효리 = new Member(org1, "민효리","직원");
var 김철수 = new Member(org1, "김철수","직원");

// %%
org1
// Out:
// 심씨네가전 유한회사

// %%
심순이
// Out:
// 심씨네가전 유한회사 심순이 사장

// %%
민효리
// Out:
// 심씨네가전 유한회사 민효리 직원

// %%
김철수
// Out:
// 심씨네가전 유한회사 김철수 직원

// %%
김철수
// Out:
// 심씨네가전 유한회사 김철수 직원

// %%
org1.setName("SS마트");
org1.setType("주식회사");

심순이.setTitle("대표이사");

김철수.setOrg(org2);

// %%
org1
// Out:
// SS마트 주식회사

// %%
심순이
// Out:
// SS마트 주식회사 심순이 대표이사

// %%
민효리
// Out:
// SS마트 주식회사 민효리 직원

// %%
김철수
// Out:
// 호호식품 주식회사 김철수 직원
